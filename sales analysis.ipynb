# %% [markdown]
# # Sales Analysis Over the Year

# %% [markdown]
# ###### In this project i analyse the sales of some products over the year in united state, this is online dataset from kaggle.

# %% [markdown]
# ### importation of libraries

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns 
import os
import re
# %matplotlib inline

# %% [markdown]
# #### loading the dataset

# %%
df = pd.read_csv('./Sales_Data/Sales_April_2019.csv')
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# #### combine all the 12 months dataset from each months

# %%
files = [file for file in os.listdir('./Sales_Data')]
all_month_data = pd.DataFrame()

for file in files:
    df = pd.read_csv('./Sales_Data/'+file)
    all_month_data = pd.concat([all_month_data, df]) 
    
all_month_data.to_csv('merged.csv')

# %% [markdown]
# #### after mergine all months data and save to csv, read from  csv

# %%
all_data = pd.read_csv('merged.csv')
all_data.head()
# Out:
#    Unnamed: 0 Order ID                     Product Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                2
# 1           1      NaN                         NaN              NaN
# 2           2   176559  Bose SoundSport Headphones                1
# 3           3   176560                Google Phone                1
# 4           4   176560            Wired Headphones                1
#
#   Price Each      Order Date                      Purchase Address
# 0      11.95  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1        NaN             NaN                                   NaN
# 2      99.99  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3        600  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4      11.99  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
all_data.shape
# Out:
# (186850, 7)

# %% [markdown]
# #### find the non values

# %%
all_data.isnull().sum()
# Out:
# Unnamed: 0            0
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
all_data.shape
# Out:
# (186850, 7)

# %% [markdown]
# #### droping the nan values provided if there is any in the table

# %%
 


all_data = all_data.dropna(how = 'any')
all_data.head()
# Out:
#    Unnamed: 0 Order ID                     Product Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                2
# 2           2   176559  Bose SoundSport Headphones                1
# 3           3   176560                Google Phone                1
# 4           4   176560            Wired Headphones                1
# 5           5   176561            Wired Headphones                1
#
#   Price Each      Order Date                      Purchase Address
# 0      11.95  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2      99.99  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3        600  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4      11.99  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5      11.99  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
all_data.shape
# Out:
# (186305, 7)

# %% [markdown]
# #### cleaning of the data

# %%
all_data = all_data[all_data['Order Date'].str[0:2] != 'Or']
all_data.head()
# Out:
#    Unnamed: 0 Order ID                     Product Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                2
# 2           2   176559  Bose SoundSport Headphones                1
# 3           3   176560                Google Phone                1
# 4           4   176560            Wired Headphones                1
# 5           5   176561            Wired Headphones                1
#
#   Price Each      Order Date                      Purchase Address
# 0      11.95  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2      99.99  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3        600  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4      11.99  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5      11.99  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])
all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int64')
all_data.head()
# Out:
#    Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                 2
# 2           2   176559  Bose SoundSport Headphones                 1
# 3           3   176560                Google Phone                 1
# 4           4   176560            Wired Headphones                 1
# 5           5   176561            Wired Headphones                 1
#
#    Price Each      Order Date                      Purchase Address  Month
# 0       11.95  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2       99.99  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3      600.00  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4       11.99  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5       11.99  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4

# %%
all_data['Sales'] = all_data['Quantity Ordered'] * all_data['Price Each']
all_data.head()
# Out:
#    Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                 2
# 2           2   176559  Bose SoundSport Headphones                 1
# 3           3   176560                Google Phone                 1
# 4           4   176560            Wired Headphones                 1
# 5           5   176561            Wired Headphones                 1
#
#    Price Each      Order Date                      Purchase Address  Month  \
# 0       11.95  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2       99.99  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3      600.00  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4       11.99  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5       11.99  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4
#
#     Sales
# 0   23.90
# 2   99.99
# 3  600.00
# 4   11.99
# 5   11.99

# %%
result = all_data.groupby('Month').sum()
result
# Out:
#        Unnamed: 0  Quantity Ordered  Price Each       Sales
# Month
# 1        47433245             10903  1811768.38  1822256.73
# 2        72123197             13449  2188884.72  2202022.42
# 3       115333587             17005  2791207.83  2807100.38
# 4       167977608             20558  3367671.02  3390670.24
# 5       137829259             18667  3135125.13  3152606.75
# 6        92330356             15253  2562025.61  2577802.26
# 7       102752005             16072  2632539.56  2647775.76
# 8        71824951             13448  2230345.42  2244467.88
# 9        67863032             13109  2084992.09  2097560.13
# 10      206528743             22703  3715554.83  3736726.88
# 11      155210546             19798  3180600.68  3199603.20
# 12      313688708             28114  4588415.41  4613443.34

# %%
from matplotlib import pyplot as plt

# %%
Month = range(1,13)

plt.bar(Month, result['Sales'])
plt.title('Sales data over the years')
plt.xticks(Month)
plt.ylabel('Sales in USD($)')
plt.xlabel('month number')
plt.show()

# %% [markdown]
# # what USA city had the highest number of sales?

# %%
all_data.head()
# Out:
#    Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                 2
# 2           2   176559  Bose SoundSport Headphones                 1
# 3           3   176560                Google Phone                 1
# 4           4   176560            Wired Headphones                 1
# 5           5   176561            Wired Headphones                 1
#
#    Price Each      Order Date                      Purchase Address  Month  \
# 0       11.95  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2       99.99  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3      600.00  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4       11.99  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5       11.99  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4
#
#     Sales
# 0   23.90
# 2   99.99
# 3  600.00
# 4   11.99
# 5   11.99

# %%
def get_city(address):
    return address.split(',')[1]

def get_state (address):
    return address.split(',')[2].split(' ')[1]



all_data['city'] = all_data['Purchase Address'].apply(lambda x: f'{get_city(x)} ({get_state(x)})')
all_data.head()
# Out:
#    Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                 2
# 2           2   176559  Bose SoundSport Headphones                 1
# 3           3   176560                Google Phone                 1
# 4           4   176560            Wired Headphones                 1
# 5           5   176561            Wired Headphones                 1
#
#    Price Each      Order Date                      Purchase Address  Month  \
# 0       11.95  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2       99.99  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3      600.00  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4       11.99  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5       11.99  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4
#
#     Sales               city
# 0   23.90        Dallas (TX)
# 2   99.99        Boston (MA)
# ...

# %%
results = all_data.groupby('city').sum()
results
# Out:
#                      Unnamed: 0  Quantity Ordered  Price Each   Month  \
# city
#  Atlanta (GA)         122928154             16602  2779908.20  104794
#  Austin (TX)           82709457             11153  1809873.61   69829
#  Boston (MA)          165758780             22528  3637409.77  141112
#  Dallas (TX)          124308328             16730  2752627.82  104620
#  Los Angeles (CA)     247743297             33289  5421435.23  208325
#  New York City (NY)   208439450             27932  4635370.83  175741
#  Portland (ME)         20641344              2750   447189.25   17144
#  Portland (OR)         83402354             11303  1860558.22   70621
#  San Francisco (CA)   372569180             50239  8211461.74  315520
#  Seattle (WA)         122394893             16553  2733296.01  104941
#
#                           Sales
# city
#  Atlanta (GA)        2795498.58
#  Austin (TX)         1819581.75
#  Boston (MA)         3661642.01
#  Dallas (TX)         2767975.40
# ...

# %%
cities = [city for city, df in all_data.groupby('city')]

plt.bar(cities, results['Sales'])
plt.title('Sales data over the years')
plt.xticks(cities, rotation='vertical', size = 8)
plt.ylabel('Sales in USD($)')
plt.xlabel('city names')
plt.show()

# %% [markdown]
# # what was the best time to display advert in order to increase the likelyhood of sales.

# %%
all_data.head()
# Out:
#    Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                 2
# 2           2   176559  Bose SoundSport Headphones                 1
# 3           3   176560                Google Phone                 1
# 4           4   176560            Wired Headphones                 1
# 5           5   176561            Wired Headphones                 1
#
#    Price Each      Order Date                      Purchase Address  Month  \
# 0       11.95  04/19/19 08:46          917 1st St, Dallas, TX 75001      4
# 2       99.99  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4
# 3      600.00  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 4       11.99  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4
# 5       11.99  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4
#
#     Sales               city
# 0   23.90        Dallas (TX)
# 2   99.99        Boston (MA)
# ...

# %%
all_data['Order Date'] = pd.to_datetime(all_data['Order Date'])

# %%
all_data.head()
# Out:
#    Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                 2
# 2           2   176559  Bose SoundSport Headphones                 1
# 3           3   176560                Google Phone                 1
# 4           4   176560            Wired Headphones                 1
# 5           5   176561            Wired Headphones                 1
#
#    Price Each          Order Date                      Purchase Address  \
# 0       11.95 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001
# 2       99.99 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215
# 3      600.00 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 4       11.99 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 5       11.99 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001
#
#    Month   Sales               city
# 0      4   23.90        Dallas (TX)
# 2      4   99.99        Boston (MA)
# ...

# %%
all_data['Hour'] = all_data['Order Date'].dt.hour
all_data['minute'] = all_data['Order Date'].dt.minute
all_data.head()
# Out:
#    Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                 2
# 2           2   176559  Bose SoundSport Headphones                 1
# 3           3   176560                Google Phone                 1
# 4           4   176560            Wired Headphones                 1
# 5           5   176561            Wired Headphones                 1
#
#    Price Each          Order Date                      Purchase Address  \
# 0       11.95 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001
# 2       99.99 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215
# 3      600.00 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 4       11.99 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 5       11.99 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001
#
#    Month   Sales               city  Hour  minute
# 0      4   23.90        Dallas (TX)     8      46
# ...

# %%
all_data['Hour'] = pd.to_datetime(all_data['Order Date']).dt.hour
all_data['Minute'] = pd.to_datetime(all_data['Order Date']).dt.minute
all_data['Count'] = 1
all_data.head()
# Out:
#    Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 0           0   176558        USB-C Charging Cable                 2
# 2           2   176559  Bose SoundSport Headphones                 1
# 3           3   176560                Google Phone                 1
# 4           4   176560            Wired Headphones                 1
# 5           5   176561            Wired Headphones                 1
#
#    Price Each          Order Date                      Purchase Address  \
# 0       11.95 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001
# 2       99.99 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215
# 3      600.00 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 4       11.99 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 5       11.99 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001
#
#    Month   Sales               city  Hour  minute  Minute  Count
# ...

# %% [markdown]
# #### My recommendation is slightly before 11am or 7pm

# %%
hours = [pair for pair, df in all_data.groupby(['Hour'])]

plt.plot(hours, all_data.groupby(['Hour']).count()['Count'])
plt.title('the best hour for advertisment')
plt.xticks(hours)
plt.grid()
plt.show()

# %% [markdown]
# ## what product are most often sold together ?

# %%
all_data_df = all_data[all_data['Order ID'].duplicated(keep = False)]
all_data_df.head()
# Out:
#     Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 3            3   176560                Google Phone                 1
# 4            4   176560            Wired Headphones                 1
# 18          18   176574                Google Phone                 1
# 19          19   176574        USB-C Charging Cable                 1
# 30          30   176585  Bose SoundSport Headphones                 1
#
#     Price Each          Order Date                      Purchase Address  \
# 3       600.00 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 4        11.99 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 18      600.00 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001
# 19       11.95 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001
# 30       99.99 2019-04-07 11:31:00     823 Highland St, Boston, MA 02215
#
#     Month   Sales               city  Hour  minute  Minute  Count
# ...

# %%
all_data_df['Grouped'] = all_data_df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
all_data_df.head()
# Out:
# C:\Users\pascal\AppData\Local\Temp\ipykernel_10420\1177755639.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data_df['Grouped'] = all_data_df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#     Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 3            3   176560                Google Phone                 1
# 4            4   176560            Wired Headphones                 1
# 18          18   176574                Google Phone                 1
# 19          19   176574        USB-C Charging Cable                 1
# 30          30   176585  Bose SoundSport Headphones                 1
#
#     Price Each          Order Date                      Purchase Address  \
# ...

# %%
all_data_df = all_data_df[['Order ID', 'Grouped']].drop_duplicates()
all_data_df.head()

# %%
all_data_df.head()
# Out:
#     Unnamed: 0 Order ID                     Product  Quantity Ordered  \
# 3            3   176560                Google Phone                 1
# 4            4   176560            Wired Headphones                 1
# 18          18   176574                Google Phone                 1
# 19          19   176574        USB-C Charging Cable                 1
# 30          30   176585  Bose SoundSport Headphones                 1
#
#     Price Each          Order Date                      Purchase Address  \
# 3       600.00 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 4        11.99 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 18      600.00 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001
# 19       11.95 2019-04-03 19:42:00     20 Hill St, Los Angeles, CA 90001
# 30       99.99 2019-04-07 11:31:00     823 Highland St, Boston, MA 02215
#
#     Month   Sales               city  Hour  minute  Minute  Count
# ...

# %%
from itertools import  combinations
from collections import Counter

# %%
product_group = all_data.groupby('Product')
quantity_ordered = product_group.sum()['Quantity Ordered']
quantity_ordered.to_excel('products.xlsx')

# %%
product_groups = product_group.sum()
product_groups.to_excel('product_group.xlsx')

# %%
product_group = all_data.groupby('Product')
quantity_ordered = product_group.sum()['Quantity Ordered']

Products = [product for product, df in product_group]

plt.bar(Products, quantity_ordered)
plt.ylabel('Quantity_ordered')
plt.xlabel('Products')
plt.xticks(Products, rotation = 'vertical', size=8)


plt.show()

# %%
prices = all_data.groupby('Product').mean()['Price Each']
prices.to_excel('product_price.xlsx')

# %%
prices = all_data.groupby('Product').mean()['Price Each']
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.bar(Products, quantity_ordered, color = 'g')
ax2.plot(Products, prices, 'b-')

ax1.set_xlabel('Product names')
ax2.set_ylabel('quantity_ordered', color = 'g')
ax2.set_ylabel('prices', color = 'b')
ax1.set_xticklabels(Products, rotation = 'vertical')
plt.show()
# Out:
# C:\Users\pascal\AppData\Local\Temp\ipykernel_12844\3273967217.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(Products, rotation = 'vertical')
